# %% [markdown]
# # Bitonic MPI

# %%
import glob
import thicket as th
import matplotlib.pyplot as plt


all_files = glob.glob("*.cali")
print(all_files)
input_types = ['Sorted', 'Random', 'Reverse Sorted', 'Perturbed']
colors = ['red', 'blue', 'green', 'orange']

for i in range(0, len(input_types)):
    procs_and_time = []
    for j in range(0, len(all_files)):
        tk = th.Thicket.from_caliperreader(all_files[j])
        if tk.metadata['InputSize'].values[0] == 65536 and tk.metadata['InputType'].values[0] == input_types[i]:
            procs_and_time.append((tk.metadata['num_procs'].values[0], tk.dataframe.iloc[0]['Total time']))
    procs_and_time = sorted(procs_and_time, key=lambda x: x[0])
    plt.plot([proc[0] for proc in procs_and_time], [time[1] for time in procs_and_time], color=colors[i], label=input_types[i])


plt.xlabel("Num Procs")
plt.ylabel("Time in Seconds")
plt.xscale('log')
plt.title("Total CUDA Execution Time: Number of Processes vs. Time for array of 65536 Values")
plt.legend()
# Out:
# ['p64-a65536.cali', 'p128-a1048576.cali', 'p64-a1048576.cali', 'p256-a65536.cali', 'p256-a16777216.cali', 'p128-a16777216.cali', 'p128-a65536.cali', 'p64-a16777216.cali', 'p256-a1048576.cali']

# %%
import glob
import thicket as th
import matplotlib.pyplot as plt


all_files = glob.glob("*.cali")
print(all_files)
input_types = ['Sorted', 'Random', 'Reverse Sorted', 'Perturbed']
colors = ['red', 'blue', 'green', 'orange']

for i in range(0, len(input_types)):
    procs_and_time = []
    for j in range(0, len(all_files)):
        tk = th.Thicket.from_caliperreader(all_files[j])
        if tk.metadata['InputSize'].values[0] == 1048576 and tk.metadata['InputType'].values[0] == input_types[i]:
            procs_and_time.append((tk.metadata['num_procs'].values[0], tk.dataframe.iloc[0]['Total time']))
    procs_and_time = sorted(procs_and_time, key=lambda x: x[0])
    plt.plot([proc[0] for proc in procs_and_time], [time[1] for time in procs_and_time], color=colors[i], label=input_types[i])


plt.xlabel("Num Procs")
plt.ylabel("Time in Seconds")
plt.xscale('log')
plt.title("Total CUDA Execution Time: Number of Processes vs. Time for array of 1048576 Values")
plt.legend()
# Out:
# ['p64-a65536.cali', 'p128-a1048576.cali', 'p64-a1048576.cali', 'p256-a65536.cali', 'p256-a16777216.cali', 'p128-a16777216.cali', 'p128-a65536.cali', 'p64-a16777216.cali', 'p256-a1048576.cali']

# %%
import glob
import thicket as th
import matplotlib.pyplot as plt


all_files = glob.glob("*.cali")
print(all_files)
input_types = ['Sorted', 'Random', 'Reverse Sorted', 'Perturbed']
colors = ['red', 'blue', 'green', 'orange']

for i in range(0, len(input_types)):
    procs_and_time = []
    for j in range(0, len(all_files)):
        tk = th.Thicket.from_caliperreader(all_files[j])
        if tk.metadata['InputSize'].values[0] == 16777216 and tk.metadata['InputType'].values[0] == input_types[i]:
            procs_and_time.append((tk.metadata['num_procs'].values[0], tk.dataframe.iloc[0]['Total time']))
    procs_and_time = sorted(procs_and_time, key=lambda x: x[0])
    plt.plot([proc[0] for proc in procs_and_time], [time[1] for time in procs_and_time], color=colors[i], label=input_types[i])


plt.xlabel("Num Procs")
plt.ylabel("Time in Seconds")
plt.xscale('log')
plt.title("Total CUDA Execution Time: Number of Processes vs. Time for array of 16777216 Values")
plt.legend()
# Out:
# ['p64-a65536.cali', 'p128-a1048576.cali', 'p64-a1048576.cali', 'p256-a65536.cali', 'p256-a16777216.cali', 'p128-a16777216.cali', 'p128-a65536.cali', 'p64-a16777216.cali', 'p256-a1048576.cali']
